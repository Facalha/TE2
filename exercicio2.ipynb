# %%
import pandas as pd
import numpy as np

# %%
dadosTabela1 = {
    'Nome': ['Anderson', 'Beatriz', 'Bruno', 'Cristiano', 'Daniel', 'Douglas', 'Elena', 'Fabricio'],
    'Chave': ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7'],
    'Chave1': ['C0', 'C1', 'C2', 'C1', 'C2', 'C1', 'C2', 'C3'],
    'Idade': [24, 25, 46, 35, 23, 20, 21, 27],
    'Cidade': ['Santos', 'Atibaia', 'Guarulhos', 'Guarulhos', 'Santos', 'Guarulhos', 'Atibaia', 'Atibaia'],
    'Registro': [32123, 32234, 32145, 49345, 98732, 99348, 99342, 28940],
    'Departamento': ['RH', 'RH', 'PD', 'ADM', 'ADM', 'ADM', 'RH', 'ADM'],
    'Formação': ['Graduação', 'Mestrado', 'Graduação', 'Técnico', 'Graduação', 'Graduação', 'Técnico', 'Graduação']
}

# %%
dadosTabela2 = {
    'Nome': ['Gabriel', 'Janaína', 'Luiz', 'Marcos', 'Nadia', 'Oswaldo', 'Patrícia', 'Ricardo'],
    'Chave': ['C0', 'C1', 'C2', 'C3', 'C1', 'C1', 'C1', 'C1'],
    'Chave1': ['C1', 'C1', 'C2', 'C2', 'C1', 'C1', 'C1', 'C1'],
    'Idade': [50, 56, 32, 29, 30, 26, 34, 38],
    'Cidade': ['Guarulhos', 'Atibaia', 'Atibaia', 'Guarulhos', 'Santos', 'Guarulhos', 'Santos', 'Santos'],
    'Registro': [13480, 34945, 56821, 99832, 65938, 65942, 77982, 45339],
    'Departamento': ['PD', 'PD', 'ADM', 'PD', 'RH', 'PD', 'ADM', 'PD'],
    'Formação': ['Técnico', 'Graduação', 'Graduação', 'Graduação', 'Graduação', 'Mestrado', 'Graduação', 'Mestrado']
}

# %%
tabela1 = pd.DataFrame(dadosTabela1)
tabela2 = pd.DataFrame(dadosTabela2)

# %%
joinInterno = pd.merge(tabela1, tabela2, on='Chave', how='inner')
print("Junção Interna:\n", joinInterno)

joinEsquerdo = pd.merge(tabela1, tabela2, on='Chave', how='left')
print("Junção Externa à Esquerda:\n", joinEsquerdo)

joinDireito = pd.merge(tabela1, tabela2, on='Chave', how='right')
print("Junção Externa à Direita:\n", joinDireito)

joinExterno = pd.merge(tabela1, tabela2, on='Chave', how='outer')
print("Junção Externa Completa:\n", joinExterno)

produtoCartesiano = tabela1.merge(tabela2, how='cross')
print("Produto Cartesiano:\n", produtoCartesiano)
# Out:
# Junção Interna:
#        Nome_x Chave Chave1_x  Idade_x   Cidade_x  Registro_x Departamento_x  \
# 0   Anderson    C0       C0       24     Santos       32123             RH
# 1    Beatriz    C1       C1       25    Atibaia       32234             RH
# 2    Beatriz    C1       C1       25    Atibaia       32234             RH
# 3    Beatriz    C1       C1       25    Atibaia       32234             RH
# 4    Beatriz    C1       C1       25    Atibaia       32234             RH
# 5    Beatriz    C1       C1       25    Atibaia       32234             RH
# 6      Bruno    C2       C2       46  Guarulhos       32145             PD
# 7  Cristiano    C3       C1       35  Guarulhos       49345            ADM
#
#   Formação_x    Nome_y Chave1_y  Idade_y   Cidade_y  Registro_y  \
# 0  Graduação   Gabriel       C1       50  Guarulhos       13480
# 1   Mestrado   Janaína       C1       56    Atibaia       34945
# 2   Mestrado     Nadia       C1       30     Santos       65938
# ...
